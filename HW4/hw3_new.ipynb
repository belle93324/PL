# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import gspread

# %%
url = 'https://www.ptt.cc/bbs/WomenTalk/index.html'
response = requests.get(url, cookies={'oer18': '1'})
response.text
if response.status_code == 200:
  soup = BeautifulSoup(response.text, 'html.parser')
soup.find_all('div', class_='class')
for article in soup.find_all('div', class_='title'):
  print(article.text.strip())
# Out:
# [閒聊] 不會被AI淘汰的蠢(?
# [閒聊] 拿坡里 必勝客 達美樂 都幾？
# [閒聊] 相親失敗，會跟女方要回飯錢嗎？
# [難過] 我是垃圾我今天好像什麼都還沒做
# [閒聊] 沒人覺得活在現代也不錯嗎？
# [閒聊] 想讓自己胸部變大吃雌激素可行嗎?
# [心情] 放棄長輩後的調適與感情茫然
# [閒聊] 有人看過恐怖家庭醫學嗎？
# [閒聊] 明天的故事都是我的 是我的
# [討論] Threads到底怎麼唸？
# Fw: [公告] 關於利用網路擄人、囚禁等議題請板主宣導
# [公告] 板規修訂預告，6/22起生效
# [公告] WomenTalk板規 (2023.6.22)
# Fw: [公告] EarthQuake43 地震專板討論

# %%
def fetch_page(url):
  response = requests.get(url, cookies={'over18': '1'})  # 繞過年齡限制
  if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    for article in soup.find_all('div', class_='title'):
      print(article.text.strip())

# %%
url = 'https://www.ptt.cc/bbs/WomenTalk/M.1713981763.A.66C.html'  # PTT 八卦版的一頁
fetch_page(url)

# %%
def fetch_pages(start_page, end_page):
  BASE_URL = 'https://www.ptt.cc'
  current_page = f'{BASE_URL}/bbs/WomenTalk/index{start_page}.html'

  for _ in range(start_page, end_page + 1):
    response = requests.get(current_page, cookies={'over18': '1'})
    if response.status_code == 200:
      soup = BeautifulSoup(response.text, 'html.parser')
      for article in soup.find_all('div', class_='title'):
        print(article.text.strip())

      # 尋找上一頁的連結，並確保它存在
      prev_link = soup.find('a', string='‹ 上頁')
      if prev_link and 'href' in prev_link.attrs:
        current_page = BASE_URL + prev_link['href']
      else:
        print("無法找到上一頁的連結，或已達起始頁面。")
        break  # 如果沒有上一頁，或找不到連結，結束迴圈
    else:
      print("無法訪問頁面，請檢查連結或網絡狀態。")
      break

# %%
fetch_pages(1, 10)
# Out:
# 恭喜開版
# ya!!!!開板了
# 輕舞飛揚
# 開版
# 恭喜...
# 哈...
# Re: 輕舞飛揚
# [公告]特此致謝
# 恭喜
# [公告]關於 WomenTalk 板/女孩們的秘密花園
# [閒聊] 恭喜開板
# 恭喜唷！
# 恭喜恭喜唷~~~~
# 耶~~唷唷
# Re: 輕舞飛揚
# 恭喜
# 嗯嗯~~^__________^
# [心得]我覺得身材真的不等於體重
# 恭喜開板
# 賀一下
# 無法找到上一頁的連結，或已達起始頁面。

# %%
class PTTGossipCrawler:
  def __init__(self):
    self.BASE_URL = 'https://www.ptt.cc'
    self.session = requests.Session()
    self.session.cookies.update({'over18': '1'})  # 自動處理年齡限制
    self.data = []  # 用來儲存文章資訊

  def fetch_article_content(self, url):
    response = self.session.get(url)
    if response.status_code != 200:
      print(f"無法訪問文章頁面 {url}")
      return None

    soup = BeautifulSoup(response.text, 'html.parser')
    try:
      # 抓取文章資訊
      meta_values = soup.find_all('span', class_='article-meta-value')
      author = meta_values[0].text
      title = meta_values[2].text
      date = meta_values[3].text
      content = soup.find(id='main-content').text
      # 這裡簡化內文提取，實際上可能需要更複雜的處理來去除非內文部分
      return {'title': title, 'author': author, 'date': date, 'content': content}
    except Exception as e:
      print(f"解析文章頁面時出錯：{url}, 錯誤：{e}")
      return None

  def fetch_pages(self, start_page, end_page):
    current_page = f'{self.BASE_URL}/bbs/WomenTalk/index{start_page}.html'

    for _ in range(start_page, end_page + 1):
      response = self.session.get(current_page)
      if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        article_links = soup.find_all('div', class_='title')
        for article in article_links:
          a_tag = article.find('a')
          if a_tag:
            article_url = self.BASE_URL + a_tag['href']
            article_data = self.fetch_article_content(article_url)
            if article_data:
              self.data.append(article_data)

        prev_link = soup.find('a', string='‹ 上頁')
        if prev_link and 'href' in prev_link.attrs:
          current_page = self.BASE_URL + prev_link['href']
        else:
            break
      else:
          break

  def to_dataframe(self):
    return pd.DataFrame(self.data)

# %%
crawler = PTTGossipCrawler()
crawler.fetch_pages(1, 10)  # 假定的頁面範圍
df = crawler.to_dataframe()
# Out:
# 解析文章頁面時出錯：https://www.ptt.cc/bbs/WomenTalk/M.1051028274.A.AF9.html, 錯誤：list index out of range

# %%
df['content'][0]
# Out:
# '作者goth (湖人贏啦)看板womentalk標題恭喜開版時間Wed Apr 23 00:12:00 2003\n\n--\n\n有什麼關係\n\n反正是夏天嘛\n\n--\n※ 發信站: 批踢踢實業坊(ptt.csie.ntu.edu.tw) \n◆ From: 218.187.32.242\n→ lladro::)                                           推  140.119.27.11 04/23\n推 idoit:..  59.115.207.59 09/27 20:26\n推 idoit:  59.115.207.59 09/27 20:35\n推 idoit:...  59.115.219.78 07/27 14:41\n→ unfearing:ID_MULTI版272和285   203.67.54.93 10/19 03:58\n推 chjna:000000000000 203.70.157.196 01/25 21:23\n推 Yimilin:... 04/29 12:16\n推 sokuso123:140.113.141.243 07/04 15:28\n噓 srxcomtx: 114.46.105.218 09/15 00:09\n推 johnny811025:  114.38.107.88 09/15 11:25\n推 mash1992: 114.38.113.202 09/16 14:52\n推 Bigfatty73  :首推   173.21.39.73 03/25 23:52\n推 NoPTT:\\⊙▽⊙/ 04/12 01:13\n推 lojyehuang: 12/14 20:18\n→ lojyehuang:如果你說的善良是指好人的話， 12/14 20:19\n→ lojyehuang:那我想，世上並沒有所謂真正的好人， 12/14 20:19\n→ lojyehuang:因為人們向來把對自己有用的人稱作好人， 12/14 20:19\n→ lojyehuang:但沒有人有辦法對所有人都有用， 12/14 20:19\n→ lojyehuang:所以這世上沒有真正善良的人的~~~ 12/14 20:19\n→ yourhighness:是否誤會了我的意思？？我從來都沒有說因為100元沒 01/31 15:45\n→ yourhighness:中而心情不好啊…… 01/31 15:45\n→ yalin0413:你同事很白目，還有那女的感覺居心不良 07/14 10:43\n→ miniblack:我還以為住多久了咧，話說是要火什麼？ 07/22 05:19\n推 niang:女友住進別人家裡真的不太得體 但是講說用肉體換 07/22 14:36\n→ niang:不覺得講得太超過了嗎 07/22 14:36\n噓 bluefish520: 噁心欸 12/02 22:23\n推 Resd: 正在準備婚禮，運氣好找到了夢幻場地，雙方家長也都讓我們 12/08 21:42\n→ Resd: 自己決定一切（這很重要）。所以幾乎都照著我們的意思走，這 12/08 21:42\n→ Resd: 樣就很夢幻了。 12/08 21:42\n推 moonpaper: 1 01/04 09:15\n推 liu83u83: 妳好像是我的臉書好友呢 01/10 18:32\n推 ghstbbit: 喜歡小唯/心宿，不喜歡美珠。柳宿算女配嗎?超愛他QQ 01/19 00:21\n推 cutefoxjai: 被電到 01/25 00:42\n推 PRAM: 恭喜 02/10 12:37\n推 zs111: 告訴我....... 02/23 00:50\n推 jimmyace: 2 03/03 22:27\n推 divahe: 南迴醫院 03/04 15:36\n噓 johnny0924: 地圖砲 03/22 01:31\n推 caramelfeng: 紅豆銅鑼燒 03/26 19:22\n推 heat0204: 水準低 就算無心 與其交往只會自取其辱 03/29 12:58\n推 huitz: 自助者天助，真的不要期待別人主動幫你 04/24 23:56\n推 yccheng: 口紅粘到牙齒 04/25 04:38\n推 huitz: 幫推，不懂一二樓在噓什麼，對於父母偏心的失望就是小 04/28 09:26\n→ huitz: 事慢慢累積起來的...不過父母也不是聖人...慢慢要學著 04/28 09:26\n→ huitz: 自己建立自己的價值，不要太在意父母的偏心 04/28 09:26\n推 huitz: 幫推，對於偏心的失望感本來就是小事慢慢累積的，我懂 04/28 09:37\n→ huitz: （拍拍 04/28 09:37\n推 liu83u83: 常常梳斷塑膠梳子，之後都改用牛角梳了，堅固又不靜電 04/29 14:39\n→ piipiiYa: 結論是靠贊助還是容易破百XD 05/07 09:45\n→ wuvwuv: 我覺得如果你不用手機的話就有資格抗議基地台會影響健康 05/09 14:38\n推 cchysteria: 真的很白目！ 05/13 13:17\n推 srwcc: 推文超爆笑的XDDDDDDDDDDDD沒有一個回對的 06/20 09:42\n推 ana5566: 都女生的毛啊 06/24 12:46\n→ std92050: 樓上皆是 DB2                                  我說謊 07/07 07:24\n噓 GauYi: 朝聖 07/09 12:16\n推 apepie: 當具備邏輯思考的能力後，我想跑spss這些統計程式應該不 07/19 09:04\n→ apepie: 難吧 07/19 09:04\n推 Rocosr: 有很多集點換itunes或gooogle play禮物卡的app啊 再換 07/25 14:17\n→ Rocosr: line代幣 貼圖買爽爽 鬼遮眼也沒差( ′ ▽ ` )ﾉ 07/25 14:17\n→ Rocosr: 多一個o... 07/25 14:17\n推 usermanual1: 突破盲點了 不推不行 年輕一代的教育真的非常地失敗! 07/27 09:29\n→ usermanual1: !不肯好好服從長輩 努力辛勤的吃苦工作 只會要求薪資 07/27 09:29\n→ usermanual1: 和福利；得不到就殺人亂說話洩憤 還把下一代也拖下水 07/27 09:29\n→ usermanual1:  過分 可惡到極點!!!以後外勞來台灣 機會越來越少 就 07/27 09:29\n→ usermanual1: 怪這群年輕人吃不了苦吧 自找的 07/27 09:29\n推 kkman2: 柯P：送我氣泡水幹嘛，加油打氣嗎？ 08/04 14:12\n推 TWYorick: 有人在ㄇ? 08/13 10:03\n噓 wth47152001: 哇哇哇看到老馬朝聖紅明顯哈哈哈 08/28 10:35\n推 CFfisher: 真的一堆推錯的欸XDDDD 09/10 20:17\n推 fortunemob: 推成績好不代表智商高～～ 09/20 14:11\n噓 sthcoming: 可以不要來這邊刷存在感嗎 09/25 13:14\n推 ShellVSX: 最近的 Altis Safety+廣告  和泰還真有臉說安全性阿 10/06 23:22\n推 moidasu: 為什麼推文會變降子XDDDDD 10/08 16:02\n推 choufang: 記念～ 10/17 03:54\n推 Fx991ESplus: 那我呢   生日大大 10/27 14:15\n推 mary0228: 噓SEEDA說男生做什麼都應該的啊 很基本吧 10/28 15:28\n→ mary0228: 嗚 推錯 噓回來 10/28 15:28\n推 usermanual1: 客觀角度看 當包租公當然很好很爽啊 可是作為一個女 10/28 20:24\n→ usermanual1: 友 如果他不用工作的時間都只是在家無所事事 而沒有 10/28 20:24\n→ usermanual1: 自發去學習或培養興趣 會覺得他根本是個沒用的人 浪 10/28 20:24\n→ usermanual1: 費時間和父母給他的房子和收到的租金 畢竟房東就是沒 10/28 20:24\n→ usermanual1: 什麼產值的職業啊 如果男方有好好利於這些時間 女方 10/28 20:24\n→ usermanual1: 也不會有這些想法吧!! 10/28 20:24\n推 prettypaty: 不管啦 長得很可愛的就不能吃啦 崩潰 11/04 09:09\n噓 prettypaty: 有點噁 你想要你旁邊的人月經來跟你一起泡嗎？ 11/06 18:00\n推 barbie0924: 你很開心齁 11/06 22:10\n推 barbie0924: 好多不相干推文 11/06 22:12\n推 usermanual1: 廢物 11/12 21:21\n推 kvhiucn: 真的啊 香到臭 在火車上大聲吵鬧 還看過脫鞋子腳伸到前面 11/16 10:34\n→ kvhiucn: 乘客的手把那邊 的== 11/16 10:34\n推 mary0228: 喜歡大誌內容所以很願意買 11/19 11:18\n噓 kvhiucn: 1 ...

# %%
from google.colab import auth
auth.authenticate_user()

import google.auth
from google.auth.transport.requests import Request
from google.colab import auth
from oauth2client.client import GoogleCredentials
from gspread import authorize

creds, _ = google.auth.default()
gc = authorize(creds)

# %%
def df_to_sheets(df, spreadsheet_id, sheet_name):
  try:
    sh = gc.open_by_key(spreadsheet_id)
  except Exception as e:
    print(f"Error opening the Spreadsheet: {e}")
    return

  try:
    worksheet = sh.worksheet(sheet_name)
  except gspread.WorksheetNotFound:
    worksheet = sh.add_worksheet(title=sheet_name, rows="100", cols="20")

  worksheet.update([df.columns.values.tolist()] + df.values.tolist())

# %%
spreadsheet_id = '13IXX3bap7S0ugjhNiWm7f77KzRNdP8ilLlPRUZB3v7A'
sheet_name = 'hw3_test'

def truncate_to_limit(cell_value, limit=10000):
  if len(cell_value) > limit:
    return cell_value[:limit] + '... [內容過長，已停止寫入]'
  else:
    return cell_value

# %%
df_truncated = df.applymap(lambda x: truncate_to_limit(str(x)))
df_truncated
# Out:
#                           title                   author  \
# 0                          恭喜開版              goth (湖人贏啦)
# 1                     ya!!!!開板了    winni318 (令人不齒的男人 丟臉)
# 2                            開版             Earl (這只是ＩＤ)
# 3                         恭喜...  chrisdove (我要眠...眠....)
# 4                          哈...     balanman (來砌磋五子棋吧~~)
# 5                      Re: 輕舞飛揚             yinting (><)
# 6                      [公告]特此致謝            lladro (三點一刻)
# 7                            恭喜        mayge (狂牛部隊真強悍!!)
# 8   [公告]關於 WomenTalk 板/女孩們的秘密花園            lladro (三點一刻)
# 9                     [閒聊] 恭喜開板           ImOnLine (now)
# 10                         恭喜唷！          sppmay (天橋在哪裡？)
# 11                    恭喜恭喜唷~~~~        jollygolu (我是愛吃鬼)
# 12                        耶~~唷唷    aya0203 (管理學....去死去死)
# 13                     Re: 輕舞飛揚       LCPallpass (祝大家幸福)
# 14                           恭喜      starset (時間靜止，一切結束)
# 15             嗯嗯~~^__________^       fish301 (郁岑家碩快快好~)
# 16             [心得]我覺得身材真的不等於體重        rabbit1014 (灰階畫布)
# 17                         恭喜開板        abacada (鋼琴大賽報名中)
# 18                          賀一下       JANKO (40分就好啦!!!!)
#
#                         date  \
# 0   Wed Apr 23 00:12:00 2003
# 1   Wed Apr 23 00:16:42 2003
# 2   Wed Apr 23 00:22:51 2003
# 3   Wed Apr 23 02:01:29 2003
# 4   Wed Apr 23 02:30:19 2003
# 5   Wed Apr 23 07:48:53 2003
# 6   Wed Apr 23 08:32:37 2003
# 7   Wed Apr 23 08:27:54 2003
# 8   Wed Apr 23 09:07:02 2003
# 9   Wed Apr 23 12:17:40 2003
# 10  Wed Apr 23 14:27:06 2003
# 11  Wed Apr 23 15:38:08 2003
# 12  Wed Apr 23 15:40:31 2003
# 13  Wed Apr 23 15:52:15 2003
# 14  Wed Apr 23 15:59:59 2003
# 15  Wed Apr 23 16:58:01 2003
# 16  Wed Apr 23 17:49:19 2003
# 17  Wed Apr 23 19:05:33 2003
# 18  Wed Apr 23 19:48:47 2003
#
#                                               content
# 0   作者goth (湖人贏啦)看板womentalk標題恭喜開版時間Wed Apr 23 00:...
# 1   作者winni318 (令人不齒的男人 丟臉)看板womentalk標題ya!!!!開板了時...
# 2   作者Earl (這只是ＩＤ)看板womentalk標題開版時間Wed Apr 23 00:2...
# 3   作者chrisdove (我要眠...眠....)看板womentalk標題恭喜...時間W...
# 4   作者balanman (來砌磋五子棋吧~~)看板womentalk標題哈...時間Wed A...
# 5   作者yinting (><)看板womentalk標題Re: 輕舞飛揚時間Wed Apr 2...
# 6   作者lladro (三點一刻)看板womentalk標題[公告]特此致謝時間Wed Apr ...
# 7   作者mayge (狂牛部隊真強悍!!)看板womentalk標題恭喜時間Wed Apr 23...
# 8   作者lladro (三點一刻)看板womentalk標題[公告]關於 WomenTalk 板...
# 9   作者ImOnLine (now)看板womentalk標題[閒聊] 恭喜開板時間Wed Ap...
# 10  作者sppmay (天橋在哪裡？)看板womentalk標題恭喜唷！時間Wed Apr 23...
# 11  作者jollygolu (我是愛吃鬼)看板womentalk標題恭喜恭喜唷~~~~時間Wed...
# 12  作者aya0203 (管理學....去死去死)看板womentalk標題耶~~唷唷時間Wed...
# 13  作者LCPallpass (祝大家幸福)看板womentalk標題Re: 輕舞飛揚時間Wed...
# 14  作者starset (時間靜止，一切結束)看板womentalk標題恭喜時間Wed Apr ...
# 15  作者fish301 (郁岑家碩快快好~)看板womentalk標題嗯嗯~~^________...
# 16  作者rabbit1014 (灰階畫布)看板womentalk標題[心得]我覺得身材真的不等於...
# 17  作者abacada (鋼琴大賽報名中)看板womentalk標題恭喜開板時間Wed Apr ...
# 18  作者JANKO (40分就好啦!!!!)看板womentalk標題賀一下時間Wed Apr ...

# %%
df_to_sheets(df_truncated, spreadsheet_id, sheet_name)
